# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv.imread('im/Im001_1.jpg')
# image = cv.cvtColor(image, cv.COLOR_RGB2BGR)
frame_hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)

plt.figure(figsize=(8, 8))
plt.subplot(121)
plt.imshow(image, cmap='gray', interpolation='nearest')
plt.subplot(122)
plt.imshow(frame_hsv, cmap='gray', interpolation='nearest')
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
mask = cv.inRange(frame_hsv, (120, 223, 0), (158, 255, 255))
# im_erode = cv.erode(mask, cv.getStructuringElement(cv.MORPH_ELLIPSE,(3,3)), iterations=1)
im_dilate = cv.dilate(im_erode, cv.getStructuringElement(cv.MORPH_ELLIPSE,(7,7)), iterations=1)

plt.figure(figsize=(16, 16))
plt.subplot(131)
plt.imshow(image, interpolation='nearest')
plt.subplot(132)
plt.imshow(mask, cmap='gray', interpolation='nearest')
plt.subplot(133)
plt.imshow(im_dilate, cmap='gray', interpolation='nearest')
plt.axis('off')

plt.tight_layout()
plt.show()
